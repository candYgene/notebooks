# %% [markdown]
# Implementation algorithm
#
# Alex Warwick Vesztrocy, Christophe Dessimoz, Henning Redestig, Prioritising candidate genes causing QTL using hierarchical orthologous groups, *Bioinformatics*, Volume 34, Issue 17, 01 September 2018, Pages i612–i619, https://doi.org/10.1093/bioinformatics/bty615

# %%
import qtlsearch
import pandas as pd
from IPython.display import Image,SVG
search = qtlsearch.SEARCH(
    "http://localhost:8890/sparql", 
    "http://sparql.omabrowser.org/sparql",
    "https://sparql.uniprot.org/sparql")

# %% [markdown]
# ## Eugenol, methyl salicylate, Guaiacol
#
# GO-terms: `GO:0042855`,  `GO:0042856`,  `GO:0042854`,  `GO:0080031`, `GO:0052689`
#
# QTL from: `Chromosome 9` : `69082273` - `69353332`
#
# Candidate: ???

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
intervalT = search.make_interval(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl/genome/Solanum_lycopersicum/chromosome/9", 
    69082273,
    69353332)


#genes for interval
genesT = search.interval_genes(intervalT)

# %% [markdown]
# Compute the list of GO annotations

# %%
qtls = [genesT.index]
go_annotations = pd.concat([
    search.get_child_annotations("GO:0042855"),
    search.get_child_annotations("GO:0042856"),
    search.get_child_annotations("GO:0042854"),
    search.get_child_annotations("GO:0080031")
    #search.get_child_annotations("GO:0052689")
])
print(go_annotations)
# Out:
#                                                                          label
# go_annotation
# http://purl.obolibrary.org/obo/GO_0042855         eugenol biosynthetic process
# http://purl.obolibrary.org/obo/GO_0042856            eugenol catabolic process
# http://purl.obolibrary.org/obo/GO_0042855         eugenol biosynthetic process
# http://purl.obolibrary.org/obo/GO_0042854            eugenol metabolic process
# http://purl.obolibrary.org/obo/GO_0042856            eugenol catabolic process
# http://purl.obolibrary.org/obo/GO_0080031  methyl salicylate esterase activity

# %% [markdown]
# Get data and do computations

# %%
result = qtlsearch.QTLSEARCH(search, qtls,go_annotations)
# Out:
# === GET DATA ===
# Search for Solyc09g083430.1
# - root is http://omabrowser.org/ontology/oma#GROUP_182708
# - tree of groups fetched: 77
# - proteins within tree fetched: 180
# - uniprot proteins within tree fetched: 149
#   * check proteins (1-180): 0 with required annotation
# - checked 149 uniprot proteins: 0 with required annotation
# - checked 180 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g083440.2
# - no groups found
# Search for Solyc09g084440.2
# - no groups found
# Search for Solyc09g084450.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143170
# - tree of groups fetched: 2
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-5): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g084460.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143170
# - tree already created
# Search for Solyc09g084470.2
# - no groups found
# Search for Solyc09g084480.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143170
# - tree already created
# Search for Solyc09g084490.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143170
# - tree already created
# Search for Solyc09g089490.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145716
# - tree of groups fetched: 5
# - proteins within tree fetched: 11
# - uniprot proteins within tree fetched: 8
#   * check proteins (1-11): 0 with required annotation
# - checked 8 uniprot proteins: 0 with required annotation
# - checked 11 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089500.2
# - no groups found
# Search for Solyc09g089510.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145716
# - tree already created
# Search for Solyc09g089520.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145716
# - tree already created
# Search for Solyc09g089530.2
# - no groups found
# Search for Solyc09g089540.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145716
# - tree already created
# Search for Solyc09g089550.2
# - root is http://omabrowser.org/ontology/oma#GROUP_144501
# - tree of groups fetched: 3
# - proteins within tree fetched: 4
# - uniprot proteins within tree fetched: 4
#   * check proteins (1-4): 0 with required annotation
# - checked 4 uniprot proteins: 0 with required annotation
# - checked 4 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089560.2
# - root is http://omabrowser.org/ontology/oma#GROUP_190503
# - tree of groups fetched: 65
# - proteins within tree fetched: 90
# - uniprot proteins within tree fetched: 81
#   * check proteins (1-90): 0 with required annotation
# - checked 81 uniprot proteins: 0 with required annotation
# - checked 90 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089570.2
# - root is http://omabrowser.org/ontology/oma#GROUP_208473
# - tree of groups fetched: 11
# - proteins within tree fetched: 15
# - uniprot proteins within tree fetched: 12
#   * check proteins (1-15): 0 with required annotation
# - checked 12 uniprot proteins: 0 with required annotation
# - checked 15 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089580.2
# - root is http://omabrowser.org/ontology/oma#GROUP_181933
# - tree of groups fetched: 74
# - proteins within tree fetched: 153
# - uniprot proteins within tree fetched: 118
#   * check proteins (1-153): 0 with required annotation
# - checked 118 uniprot proteins: 0 with required annotation
# - checked 153 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089590.1
# - root is http://omabrowser.org/ontology/oma#GROUP_191649
# - tree of groups fetched: 38
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 46
#   * check proteins (1-49): 0 with required annotation
# - checked 46 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc09g089600.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143994
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 5
#   * check proteins (1-5): 0 with required annotation
# - checked 5 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# === COMPUTATIONS ===
# Compute for Solyc09g083430.1
# Skip Solyc09g083440.2
# Skip Solyc09g084440.2
# Compute for Solyc09g084450.2
# Compute for Solyc09g084460.2
# Skip Solyc09g084470.2
# Compute for Solyc09g084480.2
# Compute for Solyc09g084490.2
# Compute for Solyc09g089490.2
# Skip Solyc09g089500.2
# Compute for Solyc09g089510.2
# Compute for Solyc09g089520.2
# Skip Solyc09g089530.2
# Compute for Solyc09g089540.2
# Compute for Solyc09g089550.2
# Compute for Solyc09g089560.2
# Compute for Solyc09g089570.2
# Compute for Solyc09g089580.2
# Compute for Solyc09g089590.1
# Compute for Solyc09g089600.1
# === CREATED QTLSEARCH OBJECT ===

# %% [markdown]
# Create report

# %%
report_list = result.report()
for report in report_list:
    display(report)
# Out:
#                   p_initial  p_final  \
# gene
# Solyc09g083430.1       0.05     0.05
# Solyc09g084450.2       0.05     0.05
# Solyc09g084460.2       0.05     0.05
# Solyc09g084480.2       0.05     0.05
# Solyc09g084490.2       0.05     0.05
# Solyc09g089490.2       0.05     0.05
# Solyc09g089510.2       0.05     0.05
# Solyc09g089520.2       0.05     0.05
# Solyc09g089540.2       0.05     0.05
# Solyc09g089550.2       0.05     0.05
# Solyc09g089560.2       0.05     0.05
# Solyc09g089570.2       0.05     0.05
# Solyc09g089580.2       0.05     0.05
# Solyc09g089590.1       0.05     0.05
# Solyc09g089600.1       0.05     0.05
#
#                                                      protein
# gene
# Solyc09g083430.1  https://omabrowser.org/oma/info/SOLLC33275
# Solyc09g084450.2  https://omabrowser.org/oma/info/SOLLC33278
# Solyc09g084460.2  https://omabrowser.org/oma/info/SOLLC33279
# Solyc09g084480.2  https://omabrowser.org/oma/info/SOLLC33281
# Solyc09g084490.2  https://omabrowser.org/oma/info/SOLLC33282
# Solyc09g089490.2  https://omabrowser.org/oma/info/SOLLC33283
# Solyc09g089510.2  https://omabrowser.org/oma/info/SOLLC33285
# Solyc09g089520.2  https://omabrowser.org/oma/info/SOLLC33286
# Solyc09g089540.2  https://omabrowser.org/oma/info/SOLLC33288
# Solyc09g089550.2  https://omabrowser.org/oma/info/SOLLC33289
# Solyc09g089560.2  https://omabrowser.org/oma/info/SOLLC33290
# Solyc09g089570.2  https://omabrowser.org/oma/info/SOLLC33291
# Solyc09g089580.2  https://omabrowser.org/oma/info/SOLLC33292
# Solyc09g089590.1  https://omabrowser.org/oma/info/SOLLC33293
# Solyc09g089600.1  https://omabrowser.org/oma/info/SOLLC33294
