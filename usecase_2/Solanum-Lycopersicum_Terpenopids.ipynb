# %% [markdown]
# Implementation algorithm
#
# Alex Warwick Vesztrocy, Christophe Dessimoz, Henning Redestig, Prioritising candidate genes causing QTL using hierarchical orthologous groups, *Bioinformatics*, Volume 34, Issue 17, 01 September 2018, Pages i612–i619, https://doi.org/10.1093/bioinformatics/bty615

# %%
import qtlsearch
import pandas as pd
from IPython.display import Image,SVG
search = qtlsearch.SEARCH(
    "http://localhost:8890/sparql", 
    "http://sparql.omabrowser.org/sparql",
    "https://sparql.uniprot.org/sparql")

# %% [markdown]
# ## Terpenoids
#
# GO-terms: `GO:0003677`, `GO:0045893`
#
# QTL from: `Chromosome 1` : `86142248` - `86467672`
#
# Candidate: `Terpense synthase`

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
intervalT = search.make_interval(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl/genome/Solanum_lycopersicum/chromosome/1", 
    86142248,
    86467672)


#genes for interval
genesT = search.interval_genes(intervalT)

# %% [markdown]
# Compute the list of GO annotations

# %%
qtls = [genesT.index]
go_annotations = pd.concat([
    search.get_child_annotations("GO:0003677"),
    search.get_child_annotations("GO:0045893")
])
print(go_annotations)
# Out:
#                                                                                        label
# go_annotation
# http://purl.obolibrary.org/obo/GO_0000406   double-strand/single-strand DNA junction binding
# http://purl.obolibrary.org/obo/GO_0001013     RNA polymerase I regulatory region DNA binding
# http://purl.obolibrary.org/obo/GO_0032138          single base insertion or deletion binding
# http://purl.obolibrary.org/obo/GO_0000986  bacterial-type proximal promoter sequence-spec...
# http://purl.obolibrary.org/obo/GO_0032810                    sterol response element binding
# ...                                                                                      ...
# http://purl.obolibrary.org/obo/GO_0097236  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_2000732  positive regulation of termination of RNA poly...
# http://purl.obolibrary.org/obo/GO_2000763  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_0061408  positive regulation of transcription from RNA ...
# http://purl.obolibrary.org/obo/GO_1900472  positive regulation of phosphatidylcholine bio...
#
# [292 rows x 1 columns]

# %% [markdown]
# Get data and do computations

# %%
result = qtlsearch.QTLSEARCH(search, qtls,go_annotations)
# Out:
# === GET DATA ===
# Search for Solyc01g094700.2
# - root is http://omabrowser.org/ontology/oma#GROUP_207160
# - tree of groups fetched: 106
# - proteins within tree fetched: 147
# - uniprot proteins within tree fetched: 141
#   * check proteins (1-147): 0 with required annotation
# - checked 141 uniprot proteins: 0 with required annotation
# - checked 147 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094710.1
# - no groups found
# Search for Solyc01g094720.2
# - root is http://omabrowser.org/ontology/oma#GROUP_502766
# - tree of groups fetched: 8804
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9979
#   * check proteins (1-10000): 0 with required annotation
# - checked 9979 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094740.1
# - root is http://omabrowser.org/ontology/oma#GROUP_144028
# - tree of groups fetched: 2
# - proteins within tree fetched: 6
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-6): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 6 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094750.2
# - root is http://omabrowser.org/ontology/oma#GROUP_513124
# - tree of groups fetched: 8340
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9988
# /Users/matthijs/opt/anaconda3/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py:1346: RuntimeWarning: unknown response content type 'text/html' returning raw response...
#   warnings.warn("unknown response content type '%s' returning raw response..." %(ct), RuntimeWarning)
#   * check proteins (1-10000): 0 with required annotation
# - checked 9988 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094760.2
# - root is http://omabrowser.org/ontology/oma#GROUP_509358
# - tree of groups fetched: 54
# - proteins within tree fetched: 77
# - uniprot proteins within tree fetched: 69
#   * check proteins (1-77): 0 with required annotation
# - checked 69 uniprot proteins: 0 with required annotation
# - checked 77 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094770.2
# - root is http://omabrowser.org/ontology/oma#GROUP_198095
# - tree of groups fetched: 53
# - proteins within tree fetched: 75
# - uniprot proteins within tree fetched: 74
#   * check proteins (1-75): 0 with required annotation
# - checked 74 uniprot proteins: 0 with required annotation
# - checked 75 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094780.2
# - root is http://omabrowser.org/ontology/oma#GROUP_214552
# - tree of groups fetched: 53
# - proteins within tree fetched: 73
# - uniprot proteins within tree fetched: 66
#   * check proteins (1-73): 0 with required annotation
# - checked 66 uniprot proteins: 0 with required annotation
# - checked 73 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094790.2
# - root is http://omabrowser.org/ontology/oma#GROUP_510573
# - tree of groups fetched: 936
# - proteins within tree fetched: 1500
# - uniprot proteins within tree fetched: 1273
#   * check proteins (1-1500): 0 with required annotation
# - checked 1273 uniprot proteins: 0 with required annotation
# - checked 1500 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094800.2
# - root is http://omabrowser.org/ontology/oma#GROUP_197789
# - tree of groups fetched: 54
# - proteins within tree fetched: 75
# - uniprot proteins within tree fetched: 71
#   * check proteins (1-75): 0 with required annotation
# - checked 71 uniprot proteins: 0 with required annotation
# - checked 75 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094810.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500249
# - tree of groups fetched: 4987
# - proteins within tree fetched: 8071
# - uniprot proteins within tree fetched: 6507
#   * check proteins (1-8071): 0 with required annotation
# - checked 6507 uniprot proteins: 0 with required annotation
# - checked 8071 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094820.2
# - root is http://omabrowser.org/ontology/oma#GROUP_187386
# - tree of groups fetched: 37
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 45
#   * check proteins (1-49): 0 with required annotation
# - checked 45 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094830.2
# - root is http://omabrowser.org/ontology/oma#GROUP_210407
# - tree of groups fetched: 91
# - proteins within tree fetched: 135
# - uniprot proteins within tree fetched: 121
#   * check proteins (1-135): 0 with required annotation
# - checked 121 uniprot proteins: 0 with required annotation
# - checked 135 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094840.2
# - root is http://omabrowser.org/ontology/oma#GROUP_213035
# - tree of groups fetched: 9
# - proteins within tree fetched: 10
# - uniprot proteins within tree fetched: 8
#   * check proteins (1-10): 0 with required annotation
# - checked 8 uniprot proteins: 0 with required annotation
# - checked 10 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094850.1
# - root is http://omabrowser.org/ontology/oma#GROUP_195699
# - tree of groups fetched: 36
# - proteins within tree fetched: 48
# - uniprot proteins within tree fetched: 41
#   * check proteins (1-48): 0 with required annotation
# - checked 41 uniprot proteins: 0 with required annotation
# - checked 48 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094860.2
# - root is http://omabrowser.org/ontology/oma#GROUP_212785
# - tree of groups fetched: 47
# - proteins within tree fetched: 69
# - uniprot proteins within tree fetched: 71
#   * check proteins (1-69): 0 with required annotation
# - checked 71 uniprot proteins: 0 with required annotation
# - checked 69 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094870.1
# - root is http://omabrowser.org/ontology/oma#GROUP_214599
# - tree of groups fetched: 104
# - proteins within tree fetched: 145
# - uniprot proteins within tree fetched: 134
#   * check proteins (1-145): 0 with required annotation
# - checked 134 uniprot proteins: 0 with required annotation
# - checked 145 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094880.2
# - root is http://omabrowser.org/ontology/oma#GROUP_506667
# - tree of groups fetched: 236
# - proteins within tree fetched: 350
# - uniprot proteins within tree fetched: 324
#   * check proteins (1-350): 0 with required annotation
# - checked 324 uniprot proteins: 0 with required annotation
# - checked 350 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094890.2
# - root is http://omabrowser.org/ontology/oma#GROUP_212756
# - tree of groups fetched: 155
# - proteins within tree fetched: 229
# - uniprot proteins within tree fetched: 224
#   * check proteins (1-229): 0 with required annotation
# - checked 224 uniprot proteins: 0 with required annotation
# - checked 229 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094900.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143606
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094910.2
# - root is http://omabrowser.org/ontology/oma#GROUP_212756
# - tree already created
# Search for Solyc01g094920.2
# - root is http://omabrowser.org/ontology/oma#GROUP_199947
# - tree of groups fetched: 40
# - proteins within tree fetched: 55
# - uniprot proteins within tree fetched: 51
#   * check proteins (1-55): 0 with required annotation
# - checked 51 uniprot proteins: 0 with required annotation
# - checked 55 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094930.2
# - root is http://omabrowser.org/ontology/oma#GROUP_712408
# - tree of groups fetched: 487
# - proteins within tree fetched: 883
# - uniprot proteins within tree fetched: 779
#   * check proteins (1-883): 0 with required annotation
# - checked 779 uniprot proteins: 0 with required annotation
# - checked 883 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094940.2
# - root is http://omabrowser.org/ontology/oma#GROUP_188003
# - tree of groups fetched: 17
# - proteins within tree fetched: 23
# - uniprot proteins within tree fetched: 19
#   * check proteins (1-23): 0 with required annotation
# - checked 19 uniprot proteins: 0 with required annotation
# - checked 23 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094950.2
# - root is http://omabrowser.org/ontology/oma#GROUP_208469
# - tree of groups fetched: 86
# - proteins within tree fetched: 111
# - uniprot proteins within tree fetched: 96
#   * check proteins (1-111): 0 with required annotation
# - checked 96 uniprot proteins: 0 with required annotation
# - checked 111 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094960.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree of groups fetched: 9999
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9997
#   * check proteins (1-10000): 0 with required annotation
# - checked 9997 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094970.2
# - root is http://omabrowser.org/ontology/oma#GROUP_714690
# - tree of groups fetched: 387
# - proteins within tree fetched: 556
# - uniprot proteins within tree fetched: 537
#   * check proteins (1-556): 0 with required annotation
# - checked 537 uniprot proteins: 0 with required annotation
# - checked 556 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g094980.1
# - no groups found
# Search for Solyc01g094990.2
# - root is http://omabrowser.org/ontology/oma#GROUP_209417
# - tree of groups fetched: 157
# - proteins within tree fetched: 249
# - uniprot proteins within tree fetched: 222
#   * check proteins (1-249): 0 with required annotation
# - checked 222 uniprot proteins: 0 with required annotation
# - checked 249 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095000.2
# - root is http://omabrowser.org/ontology/oma#GROUP_493838
# - tree of groups fetched: 53
# - proteins within tree fetched: 72
# - uniprot proteins within tree fetched: 61
#   * check proteins (1-72): 0 with required annotation
# - checked 61 uniprot proteins: 0 with required annotation
# - checked 72 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095010.2
# - root is http://omabrowser.org/ontology/oma#GROUP_509049
# - tree of groups fetched: 243
# - proteins within tree fetched: 340
# - uniprot proteins within tree fetched: 296
#   * check proteins (1-340): 0 with required annotation
# - checked 296 uniprot proteins: 0 with required annotation
# - checked 340 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095020.2
# - root is http://omabrowser.org/ontology/oma#GROUP_196111
# - tree of groups fetched: 50
# - proteins within tree fetched: 71
# - uniprot proteins within tree fetched: 62
#   * check proteins (1-71): 0 with required annotation
# - checked 62 uniprot proteins: 0 with required annotation
# - checked 71 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095030.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143816
# - tree of groups fetched: 3
# - proteins within tree fetched: 4
# - uniprot proteins within tree fetched: 4
#   * check proteins (1-4): 0 with required annotation
# - checked 4 uniprot proteins: 0 with required annotation
# - checked 4 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095040.2
# - root is http://omabrowser.org/ontology/oma#GROUP_211608
# - tree of groups fetched: 61
# - proteins within tree fetched: 84
# - uniprot proteins within tree fetched: 82
#   * check proteins (1-84): 0 with required annotation
# - checked 82 uniprot proteins: 0 with required annotation
# - checked 84 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095050.2
# - root is http://omabrowser.org/ontology/oma#GROUP_195336
# - tree of groups fetched: 35
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 41
#   * check proteins (1-49): 0 with required annotation
# - checked 41 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095060.2
# - root is http://omabrowser.org/ontology/oma#GROUP_193365
# - tree of groups fetched: 2
# - proteins within tree fetched: 3
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-3): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 3 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095070.2
# - root is http://omabrowser.org/ontology/oma#GROUP_187148
# - tree of groups fetched: 35
# - proteins within tree fetched: 46
# - uniprot proteins within tree fetched: 39
#   * check proteins (1-46): 0 with required annotation
# - checked 39 uniprot proteins: 0 with required annotation
# - checked 46 proteins: 0 linked to uniprot with required annotation
# Search for Solyc01g095080.2
# - root is http://omabrowser.org/ontology/oma#GROUP_497898
# - tree of groups fetched: 2548
# - proteins within tree fetched: 3934
# - uniprot proteins within tree fetched: 3426
#   * check proteins (1-3934): 0 with required annotation
# - checked 3426 uniprot proteins: 0 with required annotation
# - checked 3934 proteins: 0 linked to uniprot with required annotation
# === COMPUTATIONS ===
# Compute for Solyc01g094700.2
# Skip Solyc01g094710.1
# Compute for Solyc01g094720.2
# Compute for Solyc01g094740.1
# Compute for Solyc01g094750.2
# Compute for Solyc01g094760.2
# Compute for Solyc01g094770.2
# Compute for Solyc01g094780.2
# Compute for Solyc01g094790.2
# Compute for Solyc01g094800.2
# Compute for Solyc01g094810.2
# Compute for Solyc01g094820.2
# Compute for Solyc01g094830.2
# Compute for Solyc01g094840.2
# Compute for Solyc01g094850.1
# Compute for Solyc01g094860.2
# Compute for Solyc01g094870.1
# Compute for Solyc01g094880.2
# Compute for Solyc01g094890.2
# Compute for Solyc01g094900.1
# Compute for Solyc01g094910.2
# Compute for Solyc01g094920.2
# Compute for Solyc01g094930.2
# Compute for Solyc01g094940.2
# Compute for Solyc01g094950.2
# Compute for Solyc01g094960.2
# Compute for Solyc01g094970.2
# Skip Solyc01g094980.1
# Compute for Solyc01g094990.2
# Compute for Solyc01g095000.2
# Compute for Solyc01g095010.2
# Compute for Solyc01g095020.2
# Compute for Solyc01g095030.2
# Compute for Solyc01g095040.2
# Compute for Solyc01g095050.2
# Compute for Solyc01g095060.2
# Compute for Solyc01g095070.2
# Compute for Solyc01g095080.2
# === CREATED QTLSEARCH OBJECT ===

# %% [markdown]
# Create report

# %%
report_list = result.report()
for report in report_list:
    display(report)
# Out:
#                   p_initial   p_final  \
# gene
# Solyc01g094700.2   0.026316  0.026316
# Solyc01g094760.2   0.026316  0.026316
# Solyc01g094770.2   0.026316  0.026316
# Solyc01g094780.2   0.026316  0.026316
# Solyc01g094790.2   0.026316  0.026316
# Solyc01g094800.2   0.026316  0.026316
# Solyc01g094810.2   0.026316  0.026316
# Solyc01g094820.2   0.026316  0.026316
# Solyc01g094830.2   0.026316  0.026316
# Solyc01g094840.2   0.026316  0.026316
# Solyc01g094850.1   0.026316  0.026316
# Solyc01g094860.2   0.026316  0.026316
# Solyc01g094870.1   0.026316  0.026316
# Solyc01g094880.2   0.026316  0.026316
# Solyc01g094890.2   0.026316  0.026316
# Solyc01g094900.1   0.026316  0.026316
# Solyc01g094910.2   0.026316  0.026316
# Solyc01g094920.2   0.026316  0.026316
# Solyc01g094930.2   0.026316  0.026316
# Solyc01g094940.2   0.026316  0.026316
# Solyc01g094950.2   0.026316  0.026316
# Solyc01g094970.2   0.026316  0.026316
# Solyc01g094990.2   0.026316  0.026316
# Solyc01g095000.2   0.026316  0.026316
# Solyc01g095010.2   0.026316  0.026316
# Solyc01g095020.2   0.026316  0.026316
# Solyc01g095030.2   0.026316  0.026316
# Solyc01g095040.2   0.026316  0.026316
# Solyc01g095050.2   0.026316  0.026316
# Solyc01g095060.2   0.026316  0.026316
# Solyc01g095070.2   0.026316  0.026316
# Solyc01g095080.2   0.026316  0.026316
# Solyc01g094720.2   0.026316  0.000000
# Solyc01g094740.1   0.026316  0.000000
# Solyc01g094750.2   0.026316  0.000000
# Solyc01g094960.2   0.026316  0.000000
#
#                                                      protein
# gene
# Solyc01g094700.2  https://omabrowser.org/oma/info/SOLLC02611
# Solyc01g094760.2  https://omabrowser.org/oma/info/SOLLC02616
# Solyc01g094770.2  https://omabrowser.org/oma/info/SOLLC02617
# Solyc01g094780.2  https://omabrowser.org/oma/info/SOLLC02618
# Solyc01g094790.2  https://omabrowser.org/oma/info/SOLLC02619
# Solyc01g094800.2  https://omabrowser.org/oma/info/SOLLC02620
# Solyc01g094810.2  https://omabrowser.org/oma/info/SOLLC02621
# Solyc01g094820.2  https://omabrowser.org/oma/info/SOLLC02622
# Solyc01g094830.2  https://omabrowser.org/oma/info/SOLLC02623
# Solyc01g094840.2  https://omabrowser.org/oma/info/SOLLC02624
# Solyc01g094850.1  https://omabrowser.org/oma/info/SOLLC02625
# Solyc01g094860.2  https://omabrowser.org/oma/info/SOLLC02626
# Solyc01g094870.1  https://omabrowser.org/oma/info/SOLLC02627
# Solyc01g094880.2  https://omabrowser.org/oma/info/SOLLC02628
# Solyc01g094890.2  https://omabrowser.org/oma/info/SOLLC02629
# Solyc01g094900.1  https://omabrowser.org/oma/info/SOLLC02630
# Solyc01g094910.2  https://omabrowser.org/oma/info/SOLLC02631
# Solyc01g094920.2  https://omabrowser.org/oma/info/SOLLC02632
# Solyc01g094930.2  https://omabrowser.org/oma/info/SOLLC02633
# Solyc01g094940.2  https://omabrowser.org/oma/info/SOLLC02634
# Solyc01g094950.2  https://omabrowser.org/oma/info/SOLLC02635
# Solyc01g094970.2  https://omabrowser.org/oma/info/SOLLC02637
# Solyc01g094990.2  https://omabrowser.org/oma/info/SOLLC02639
# Solyc01g095000.2  https://omabrowser.org/oma/info/SOLLC02640
# Solyc01g095010.2  https://omabrowser.org/oma/info/SOLLC02641
# Solyc01g095020.2  https://omabrowser.org/oma/info/SOLLC02642
# Solyc01g095030.2  https://omabrowser.org/oma/info/SOLLC02643
# Solyc01g095040.2  https://omabrowser.org/oma/info/SOLLC02644
# Solyc01g095050.2  https://omabrowser.org/oma/info/SOLLC02645
# Solyc01g095060.2  https://omabrowser.org/oma/info/SOLLC02646
# Solyc01g095070.2  https://omabrowser.org/oma/info/SOLLC02647
# Solyc01g095080.2  https://omabrowser.org/oma/info/SOLLC02648
# Solyc01g094720.2  https://omabrowser.org/oma/info/SOLLC02613
# Solyc01g094740.1  https://omabrowser.org/oma/info/SOLLC02614
# Solyc01g094750.2  https://omabrowser.org/oma/info/SOLLC02615
# Solyc01g094960.2  https://omabrowser.org/oma/info/SOLLC02636
