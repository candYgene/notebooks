# %% [markdown]
# Implementation algorithm
#
# Alex Warwick Vesztrocy, Christophe Dessimoz, Henning Redestig, Prioritising candidate genes causing QTL using hierarchical orthologous groups, *Bioinformatics*, Volume 34, Issue 17, 01 September 2018, Pages i612–i619, https://doi.org/10.1093/bioinformatics/bty615

# %%
import qtlsearch
import pandas as pd
from IPython.display import Image,SVG
search = qtlsearch.SEARCH(
    "http://localhost:8890/sparql", 
    "http://sparql.omabrowser.org/sparql",
    "https://sparql.uniprot.org/sparql")

# %% [markdown]
# ## Volatiles compounds, branched-chain amino acid, 3-methylbuthanal 3-methylbuthanol
#
# GO-terms: `GO:0046568`, `GO:0018455`, `GO:0052676`
#
# QTL from: `Chromosome 3` : `69685329` - `71362039`
#
# Candidate: ???

# %% [markdown]
# Define the QTL and compute genes within this interval

# %%
intervalT = search.make_interval(
    "http://pbg-ld.candygene-nlesc.surf-hosted.nl/genome/Solanum_lycopersicum/chromosome/3", 
    69685329,71362039)


#genes for interval
genesT = search.interval_genes(intervalT)

# %% [markdown]
# Compute the list of GO annotations

# %%
qtls = [genesT.index]
go_annotations = pd.concat([
    search.get_child_annotations("GO:0018455"),
    search.get_child_annotations("GO:0052676")
])
print(go_annotations)
# Out:
#                                                                                     label
# go_annotation
# http://purl.obolibrary.org/obo/GO_0018455        alcohol dehydrogenase [NAD(P)+] activity
# http://purl.obolibrary.org/obo/GO_0046568  3-methylbutanol:NAD(P) oxidoreductase activity
# http://purl.obolibrary.org/obo/GO_0052676     3-methylbutanol:NAD oxidoreductase activity

# %% [markdown]
# Get data and do computations

# %%
result = qtlsearch.QTLSEARCH(search, qtls,go_annotations)
# Out:
# === GET DATA ===
# Search for Solyc03g121600.2
# - root is http://omabrowser.org/ontology/oma#GROUP_511499
# - tree of groups fetched: 1555
# - proteins within tree fetched: 2902
# - uniprot proteins within tree fetched: 2207
#   * check proteins (1-2902): 0 with required annotation
# - checked 2207 uniprot proteins: 0 with required annotation
# - checked 2902 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121610.2
# - root is http://omabrowser.org/ontology/oma#GROUP_191868
# - tree of groups fetched: 12
# - proteins within tree fetched: 16
# - uniprot proteins within tree fetched: 14
#   * check proteins (1-16): 0 with required annotation
# - checked 14 uniprot proteins: 0 with required annotation
# - checked 16 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121620.1
# - root is http://omabrowser.org/ontology/oma#GROUP_203811
# - tree of groups fetched: 123
# - proteins within tree fetched: 174
# - uniprot proteins within tree fetched: 155
#   * check proteins (1-174): 0 with required annotation
# - checked 155 uniprot proteins: 0 with required annotation
# - checked 174 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121630.2
# - root is http://omabrowser.org/ontology/oma#GROUP_503623
# - tree of groups fetched: 42
# - proteins within tree fetched: 67
# - uniprot proteins within tree fetched: 62
#   * check proteins (1-67): 0 with required annotation
# - checked 62 uniprot proteins: 0 with required annotation
# - checked 67 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121640.2
# - root is http://omabrowser.org/ontology/oma#GROUP_717202
# - tree of groups fetched: 3809
# - proteins within tree fetched: 6858
# - uniprot proteins within tree fetched: 6245
#   * check proteins (1-6858): 0 with required annotation
# - checked 6245 uniprot proteins: 0 with required annotation
# - checked 6858 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121650.2
# - root is http://omabrowser.org/ontology/oma#GROUP_147012
# - tree of groups fetched: 5
# - proteins within tree fetched: 6
# - uniprot proteins within tree fetched: 6
#   * check proteins (1-6): 0 with required annotation
# - checked 6 uniprot proteins: 0 with required annotation
# - checked 6 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121660.2
# - root is http://omabrowser.org/ontology/oma#GROUP_185000
# - tree of groups fetched: 7
# - proteins within tree fetched: 9
# - uniprot proteins within tree fetched: 9
#   * check proteins (1-9): 0 with required annotation
# - checked 9 uniprot proteins: 0 with required annotation
# - checked 9 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121670.2
# - root is http://omabrowser.org/ontology/oma#GROUP_498827
# - tree of groups fetched: 192
# - proteins within tree fetched: 280
# - uniprot proteins within tree fetched: 237
#   * check proteins (1-280): 0 with required annotation
# - checked 237 uniprot proteins: 0 with required annotation
# - checked 280 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121680.1
# - root is http://omabrowser.org/ontology/oma#GROUP_495908
# - tree of groups fetched: 451
# - proteins within tree fetched: 717
# - uniprot proteins within tree fetched: 752
#   * check proteins (1-717): 0 with required annotation
# - checked 752 uniprot proteins: 0 with required annotation
# - checked 717 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121690.1
# - root is http://omabrowser.org/ontology/oma#GROUP_182410
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 5
#   * check proteins (1-5): 0 with required annotation
# - checked 5 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121700.2
# - root is http://omabrowser.org/ontology/oma#GROUP_493314
# - tree of groups fetched: 577
# - proteins within tree fetched: 933
# - uniprot proteins within tree fetched: 803
#   * check proteins (1-933): 0 with required annotation
# - checked 803 uniprot proteins: 0 with required annotation
# - checked 933 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121710.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree of groups fetched: 9999
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9997
# /Users/matthijs/opt/anaconda3/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py:1346: RuntimeWarning: unknown response content type 'text/html' returning raw response...
#   warnings.warn("unknown response content type '%s' returning raw response..." %(ct), RuntimeWarning)
#   * check proteins (1-10000): 0 with required annotation
# - checked 9997 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121720.2
# - root is http://omabrowser.org/ontology/oma#GROUP_499657
# - tree of groups fetched: 648
# - proteins within tree fetched: 991
# - uniprot proteins within tree fetched: 826
#   * check proteins (1-991): 0 with required annotation
# - checked 826 uniprot proteins: 0 with required annotation
# - checked 991 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121730.2
# - root is http://omabrowser.org/ontology/oma#GROUP_213049
# - tree of groups fetched: 74
# - proteins within tree fetched: 102
# - uniprot proteins within tree fetched: 92
#   * check proteins (1-102): 0 with required annotation
# - checked 92 uniprot proteins: 0 with required annotation
# - checked 102 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121740.1
# - root is http://omabrowser.org/ontology/oma#GROUP_144983
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 4
#   * check proteins (1-5): 0 with required annotation
# - checked 4 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121750.1
# - no groups found
# Search for Solyc03g121760.2
# - root is http://omabrowser.org/ontology/oma#GROUP_184515
# - tree of groups fetched: 36
# - proteins within tree fetched: 43
# - uniprot proteins within tree fetched: 43
#   * check proteins (1-43): 0 with required annotation
# - checked 43 uniprot proteins: 0 with required annotation
# - checked 43 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121770.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143788
# - tree of groups fetched: 2
# - proteins within tree fetched: 3
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-3): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 3 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121780.1
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree already created
# Search for Solyc03g121790.2
# - root is http://omabrowser.org/ontology/oma#GROUP_187064
# - tree of groups fetched: 6
# - proteins within tree fetched: 7
# - uniprot proteins within tree fetched: 7
#   * check proteins (1-7): 0 with required annotation
# - checked 7 uniprot proteins: 0 with required annotation
# - checked 7 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121800.2
# - root is http://omabrowser.org/ontology/oma#GROUP_504755
# - tree of groups fetched: 427
# - proteins within tree fetched: 645
# - uniprot proteins within tree fetched: 544
#   * check proteins (1-645): 0 with required annotation
# - checked 544 uniprot proteins: 0 with required annotation
# - checked 645 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121810.2
# - root is http://omabrowser.org/ontology/oma#GROUP_511598
# - tree of groups fetched: 4325
# - proteins within tree fetched: 6932
# - uniprot proteins within tree fetched: 6481
#   * check proteins (1-6932): 0 with required annotation
# - checked 6481 uniprot proteins: 0 with required annotation
# - checked 6932 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121820.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree already created
# Search for Solyc03g121830.1
# - root is http://omabrowser.org/ontology/oma#GROUP_505869
# - tree of groups fetched: 434
# - proteins within tree fetched: 672
# - uniprot proteins within tree fetched: 545
#   * check proteins (1-672): 0 with required annotation
# - checked 545 uniprot proteins: 0 with required annotation
# - checked 672 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121840.2
# - root is http://omabrowser.org/ontology/oma#GROUP_204636
# - tree of groups fetched: 63
# - proteins within tree fetched: 88
# - uniprot proteins within tree fetched: 82
#   * check proteins (1-88): 0 with required annotation
# - checked 82 uniprot proteins: 0 with required annotation
# - checked 88 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121850.2
# - root is http://omabrowser.org/ontology/oma#GROUP_195266
# - tree of groups fetched: 19
# - proteins within tree fetched: 27
# - uniprot proteins within tree fetched: 22
#   * check proteins (1-27): 0 with required annotation
# - checked 22 uniprot proteins: 0 with required annotation
# - checked 27 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121860.1
# - root is http://omabrowser.org/ontology/oma#GROUP_497980
# - tree of groups fetched: 209
# - proteins within tree fetched: 328
# - uniprot proteins within tree fetched: 280
#   * check proteins (1-328): 0 with required annotation
# - checked 280 uniprot proteins: 0 with required annotation
# - checked 328 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121870.2
# - root is http://omabrowser.org/ontology/oma#GROUP_507992
# - tree of groups fetched: 249
# - proteins within tree fetched: 368
# - uniprot proteins within tree fetched: 326
#   * check proteins (1-368): 0 with required annotation
# - checked 326 uniprot proteins: 0 with required annotation
# - checked 368 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121880.2
# - no groups found
# Search for Solyc03g121890.1
# - root is http://omabrowser.org/ontology/oma#GROUP_196523
# - tree of groups fetched: 34
# - proteins within tree fetched: 46
# - uniprot proteins within tree fetched: 41
#   * check proteins (1-46): 0 with required annotation
# - checked 41 uniprot proteins: 0 with required annotation
# - checked 46 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121900.1
# - root is http://omabrowser.org/ontology/oma#GROUP_199132
# - tree of groups fetched: 18
# - proteins within tree fetched: 27
# - uniprot proteins within tree fetched: 21
#   * check proteins (1-27): 0 with required annotation
# - checked 21 uniprot proteins: 0 with required annotation
# - checked 27 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121910.1
# - root is http://omabrowser.org/ontology/oma#GROUP_512598
# - tree of groups fetched: 94
# - proteins within tree fetched: 137
# - uniprot proteins within tree fetched: 121
#   * check proteins (1-137): 0 with required annotation
# - checked 121 uniprot proteins: 0 with required annotation
# - checked 137 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121920.2
# - root is http://omabrowser.org/ontology/oma#GROUP_498805
# - tree of groups fetched: 6656
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 8762
#   * check proteins (1-10000): 0 with required annotation
# - checked 8762 uniprot proteins: 0 with required annotation
# - checked 10000 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121930.2
# - root is http://omabrowser.org/ontology/oma#GROUP_142470
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121940.2
# - root is http://omabrowser.org/ontology/oma#GROUP_184261
# - tree of groups fetched: 35
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 50
#   * check proteins (1-49): 0 with required annotation
# - checked 50 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121950.2
# - root is http://omabrowser.org/ontology/oma#GROUP_495240
# - tree of groups fetched: 65
# - proteins within tree fetched: 88
# - uniprot proteins within tree fetched: 82
#   * check proteins (1-88): 0 with required annotation
# - checked 82 uniprot proteins: 0 with required annotation
# - checked 88 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121960.2
# - root is http://omabrowser.org/ontology/oma#GROUP_494331
# - tree of groups fetched: 197
# - proteins within tree fetched: 304
# - uniprot proteins within tree fetched: 272
#   * check proteins (1-304): 0 with required annotation
# - checked 272 uniprot proteins: 0 with required annotation
# - checked 304 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121970.1
# - root is http://omabrowser.org/ontology/oma#GROUP_197387
# - tree of groups fetched: 59
# - proteins within tree fetched: 79
# - uniprot proteins within tree fetched: 79
#   * check proteins (1-79): 0 with required annotation
# - checked 79 uniprot proteins: 0 with required annotation
# - checked 79 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121980.2
# - root is http://omabrowser.org/ontology/oma#GROUP_706238
# - tree of groups fetched: 715
# - proteins within tree fetched: 1167
# - uniprot proteins within tree fetched: 996
#   * check proteins (1-1167): 0 with required annotation
# - checked 996 uniprot proteins: 0 with required annotation
# - checked 1167 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g121990.2
# - root is http://omabrowser.org/ontology/oma#GROUP_195762
# - tree of groups fetched: 49
# - proteins within tree fetched: 68
# - uniprot proteins within tree fetched: 80
#   * check proteins (1-68): 0 with required annotation
# - checked 80 uniprot proteins: 0 with required annotation
# - checked 68 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122000.2
# - no groups found
# Search for Solyc03g122010.1
# - root is http://omabrowser.org/ontology/oma#GROUP_145096
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122020.2
# - root is http://omabrowser.org/ontology/oma#GROUP_206395
# - tree of groups fetched: 45
# - proteins within tree fetched: 59
# - uniprot proteins within tree fetched: 55
#   * check proteins (1-59): 0 with required annotation
# - checked 55 uniprot proteins: 0 with required annotation
# - checked 59 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122030.1
# - root is http://omabrowser.org/ontology/oma#GROUP_186116
# - tree of groups fetched: 34
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 34
#   * check proteins (1-49): 0 with required annotation
# - checked 34 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122040.2
# - root is http://omabrowser.org/ontology/oma#GROUP_205142
# - tree of groups fetched: 59
# - proteins within tree fetched: 83
# - uniprot proteins within tree fetched: 80
#   * check proteins (1-83): 0 with required annotation
# - checked 80 uniprot proteins: 0 with required annotation
# - checked 83 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122050.1
# - no groups found
# Search for Solyc03g122060.1
# - no groups found
# Search for Solyc03g122070.1
# - root is http://omabrowser.org/ontology/oma#GROUP_506991
# - tree of groups fetched: 9999
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9992
#   * check proteins (1-10000): 0 with required annotation
# - checked 9992 uniprot proteins: 0 with required annotation
# - checked 10000 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122080.2
# - root is http://omabrowser.org/ontology/oma#GROUP_195625
# - tree of groups fetched: 44
# - proteins within tree fetched: 60
# - uniprot proteins within tree fetched: 55
#   * check proteins (1-60): 0 with required annotation
# - checked 55 uniprot proteins: 0 with required annotation
# - checked 60 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122090.2
# - root is http://omabrowser.org/ontology/oma#GROUP_513558
# - tree of groups fetched: 1056
# - proteins within tree fetched: 1608
# - uniprot proteins within tree fetched: 1362
#   * check proteins (1-1608): 0 with required annotation
# - checked 1362 uniprot proteins: 0 with required annotation
# - checked 1608 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122100.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143467
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122110.1
# - root is http://omabrowser.org/ontology/oma#GROUP_494472
# - tree of groups fetched: 289
# - proteins within tree fetched: 461
# - uniprot proteins within tree fetched: 351
#   * check proteins (1-461): 0 with required annotation
# - checked 351 uniprot proteins: 0 with required annotation
# - checked 461 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122120.2
# - root is http://omabrowser.org/ontology/oma#GROUP_717740
# - tree of groups fetched: 529
# - proteins within tree fetched: 802
# - uniprot proteins within tree fetched: 692
#   * check proteins (1-802): 0 with required annotation
# - checked 692 uniprot proteins: 0 with required annotation
# - checked 802 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122130.2
# - root is http://omabrowser.org/ontology/oma#GROUP_709201
# - tree of groups fetched: 1286
# - proteins within tree fetched: 2374
# - uniprot proteins within tree fetched: 2079
#   * check proteins (1-2374): 0 with required annotation
# - checked 2079 uniprot proteins: 0 with required annotation
# - checked 2374 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122140.2
# - root is http://omabrowser.org/ontology/oma#GROUP_709201
# - tree already created
# Search for Solyc03g122150.2
# - root is http://omabrowser.org/ontology/oma#GROUP_708463
# - tree of groups fetched: 12
# - proteins within tree fetched: 16
# - uniprot proteins within tree fetched: 11
#   * check proteins (1-16): 0 with required annotation
# - checked 11 uniprot proteins: 0 with required annotation
# - checked 16 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122160.1
# - no groups found
# Search for Solyc03g122170.2
# - root is http://omabrowser.org/ontology/oma#GROUP_709201
# - tree already created
# Search for Solyc03g122180.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree already created
# Search for Solyc03g122190.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145289
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 5
#   * check proteins (1-5): 0 with required annotation
# - checked 5 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122200.1
# - root is http://omabrowser.org/ontology/oma#GROUP_180150
# - tree of groups fetched: 3
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 1
#   * check proteins (1-5): 0 with required annotation
# - checked 1 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122210.1
# - root is http://omabrowser.org/ontology/oma#GROUP_142649
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 1
#   * check proteins (1-2): 0 with required annotation
# - checked 1 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122220.1
# - root is http://omabrowser.org/ontology/oma#GROUP_144515
# - tree of groups fetched: 5
# - proteins within tree fetched: 25
# - uniprot proteins within tree fetched: 21
#   * check proteins (1-25): 0 with required annotation
# - checked 21 uniprot proteins: 0 with required annotation
# - checked 25 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122230.1
# - root is http://omabrowser.org/ontology/oma#GROUP_194885
# - tree of groups fetched: 66
# - proteins within tree fetched: 92
# - uniprot proteins within tree fetched: 81
#   * check proteins (1-92): 0 with required annotation
# - checked 81 uniprot proteins: 0 with required annotation
# - checked 92 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122240.2
# - root is http://omabrowser.org/ontology/oma#GROUP_209230
# - tree of groups fetched: 81
# - proteins within tree fetched: 109
# - uniprot proteins within tree fetched: 108
#   * check proteins (1-109): 0 with required annotation
# - checked 108 uniprot proteins: 0 with required annotation
# - checked 109 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122250.2
# - root is http://omabrowser.org/ontology/oma#GROUP_496065
# - tree of groups fetched: 183
# - proteins within tree fetched: 262
# - uniprot proteins within tree fetched: 240
#   * check proteins (1-262): 0 with required annotation
# - checked 240 uniprot proteins: 0 with required annotation
# - checked 262 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122260.2
# - root is http://omabrowser.org/ontology/oma#GROUP_500547
# - tree of groups fetched: 249
# - proteins within tree fetched: 365
# - uniprot proteins within tree fetched: 289
#   * check proteins (1-365): 0 with required annotation
# - checked 289 uniprot proteins: 0 with required annotation
# - checked 365 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122270.2
# - root is http://omabrowser.org/ontology/oma#GROUP_213832
# - tree of groups fetched: 107
# - proteins within tree fetched: 149
# - uniprot proteins within tree fetched: 147
#   * check proteins (1-149): 0 with required annotation
# - checked 147 uniprot proteins: 0 with required annotation
# - checked 149 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122280.2
# - no groups found
# Search for Solyc03g122290.2
# - root is http://omabrowser.org/ontology/oma#GROUP_196959
# - tree of groups fetched: 40
# - proteins within tree fetched: 56
# - uniprot proteins within tree fetched: 51
#   * check proteins (1-56): 0 with required annotation
# - checked 51 uniprot proteins: 0 with required annotation
# - checked 56 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122300.1
# - root is http://omabrowser.org/ontology/oma#GROUP_147303
# - tree of groups fetched: 12
# - proteins within tree fetched: 15
# - uniprot proteins within tree fetched: 15
#   * check proteins (1-15): 0 with required annotation
# - checked 15 uniprot proteins: 0 with required annotation
# - checked 15 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122310.2
# - root is http://omabrowser.org/ontology/oma#GROUP_717648
# - tree of groups fetched: 3286
# - proteins within tree fetched: 5642
# - uniprot proteins within tree fetched: 5071
#   * check proteins (1-5642): 0 with required annotation
# - checked 5071 uniprot proteins: 0 with required annotation
# - checked 5642 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122320.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143156
# - tree of groups fetched: 3
# - proteins within tree fetched: 6
# - uniprot proteins within tree fetched: 7
#   * check proteins (1-6): 0 with required annotation
# - checked 7 uniprot proteins: 0 with required annotation
# - checked 6 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122330.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143156
# - tree already created
# Search for Solyc03g122340.2
# - root is http://omabrowser.org/ontology/oma#GROUP_212741
# - tree of groups fetched: 177
# - proteins within tree fetched: 289
# - uniprot proteins within tree fetched: 268
#   * check proteins (1-289): 0 with required annotation
# - checked 268 uniprot proteins: 0 with required annotation
# - checked 289 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122350.2
# - root is http://omabrowser.org/ontology/oma#GROUP_513124
# - tree of groups fetched: 8340
# - proteins within tree fetched: 10000
# - uniprot proteins within tree fetched: 9988
#   * check proteins (1-10000): 0 with required annotation
# - checked 9988 uniprot proteins: 0 with required annotation
# - checked 10001 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g122360.2
# - root is http://omabrowser.org/ontology/oma#GROUP_513124
# - tree already created
# Search for Solyc03g122370.2
# - root is http://omabrowser.org/ontology/oma#GROUP_499143
# - tree of groups fetched: 244
# - proteins within tree fetched: 371
# - uniprot proteins within tree fetched: 357
#   * check proteins (1-371): 0 with required annotation
# - checked 357 uniprot proteins: 0 with required annotation
# - checked 371 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123370.2
# - root is http://omabrowser.org/ontology/oma#GROUP_208089
# - tree of groups fetched: 69
# - proteins within tree fetched: 98
# - uniprot proteins within tree fetched: 92
#   * check proteins (1-98): 0 with required annotation
# - checked 92 uniprot proteins: 0 with required annotation
# - checked 98 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123380.1
# - root is http://omabrowser.org/ontology/oma#GROUP_179690
# - tree of groups fetched: 12
# - proteins within tree fetched: 18
# - uniprot proteins within tree fetched: 15
#   * check proteins (1-18): 0 with required annotation
# - checked 15 uniprot proteins: 0 with required annotation
# - checked 18 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123390.2
# - root is http://omabrowser.org/ontology/oma#GROUP_202910
# - tree of groups fetched: 42
# - proteins within tree fetched: 55
# - uniprot proteins within tree fetched: 56
#   * check proteins (1-55): 0 with required annotation
# - checked 56 uniprot proteins: 0 with required annotation
# - checked 55 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123400.1
# - root is http://omabrowser.org/ontology/oma#GROUP_207243
# - tree of groups fetched: 48
# - proteins within tree fetched: 61
# - uniprot proteins within tree fetched: 63
#   * check proteins (1-61): 0 with required annotation
# - checked 63 uniprot proteins: 0 with required annotation
# - checked 61 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123410.1
# - root is http://omabrowser.org/ontology/oma#GROUP_197978
# - tree of groups fetched: 68
# - proteins within tree fetched: 101
# - uniprot proteins within tree fetched: 97
#   * check proteins (1-101): 0 with required annotation
# - checked 97 uniprot proteins: 0 with required annotation
# - checked 101 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123420.1
# - root is http://omabrowser.org/ontology/oma#GROUP_185349
# - tree of groups fetched: 21
# - proteins within tree fetched: 28
# - uniprot proteins within tree fetched: 24
#   * check proteins (1-28): 0 with required annotation
# - checked 24 uniprot proteins: 0 with required annotation
# - checked 28 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123430.2
# - root is http://omabrowser.org/ontology/oma#GROUP_183775
# - tree of groups fetched: 16
# - proteins within tree fetched: 25
# - uniprot proteins within tree fetched: 29
#   * check proteins (1-25): 0 with required annotation
# - checked 29 uniprot proteins: 0 with required annotation
# - checked 25 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123440.2
# - root is http://omabrowser.org/ontology/oma#GROUP_143558
# - tree of groups fetched: 2
# - proteins within tree fetched: 3
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-3): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 3 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123450.1
# - no groups found
# Search for Solyc03g123460.2
# - root is http://omabrowser.org/ontology/oma#GROUP_144320
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 5
#   * check proteins (1-5): 0 with required annotation
# - checked 5 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123470.1
# - root is http://omabrowser.org/ontology/oma#GROUP_180336
# - tree of groups fetched: 0
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 0
# - checked 0 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123480.1
# - no groups found
# Search for Solyc03g123490.1
# - root is http://omabrowser.org/ontology/oma#GROUP_206577
# - tree of groups fetched: 82
# - proteins within tree fetched: 122
# - uniprot proteins within tree fetched: 98
#   * check proteins (1-122): 0 with required annotation
# - checked 98 uniprot proteins: 0 with required annotation
# - checked 122 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123500.2
# - root is http://omabrowser.org/ontology/oma#GROUP_193778
# - tree of groups fetched: 70
# - proteins within tree fetched: 94
# - uniprot proteins within tree fetched: 98
#   * check proteins (1-94): 0 with required annotation
# - checked 98 uniprot proteins: 0 with required annotation
# - checked 94 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123510.1
# - root is http://omabrowser.org/ontology/oma#GROUP_198654
# - tree of groups fetched: 25
# - proteins within tree fetched: 33
# - uniprot proteins within tree fetched: 30
#   * check proteins (1-33): 0 with required annotation
# - checked 30 uniprot proteins: 0 with required annotation
# - checked 33 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123520.2
# - root is http://omabrowser.org/ontology/oma#GROUP_504256
# - tree of groups fetched: 686
# - proteins within tree fetched: 1065
# - uniprot proteins within tree fetched: 997
#   * check proteins (1-1065): 0 with required annotation
# - checked 997 uniprot proteins: 0 with required annotation
# - checked 1065 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123530.2
# - root is http://omabrowser.org/ontology/oma#GROUP_504322
# - tree of groups fetched: 277
# - proteins within tree fetched: 419
# - uniprot proteins within tree fetched: 410
#   * check proteins (1-419): 0 with required annotation
# - checked 410 uniprot proteins: 0 with required annotation
# - checked 419 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123540.2
# - root is http://omabrowser.org/ontology/oma#GROUP_204392
# - tree of groups fetched: 41
# - proteins within tree fetched: 56
# - uniprot proteins within tree fetched: 52
#   * check proteins (1-56): 0 with required annotation
# - checked 52 uniprot proteins: 0 with required annotation
# - checked 56 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123550.1
# - root is http://omabrowser.org/ontology/oma#GROUP_182552
# - tree of groups fetched: 15
# - proteins within tree fetched: 21
# - uniprot proteins within tree fetched: 14
#   * check proteins (1-21): 0 with required annotation
# - checked 14 uniprot proteins: 0 with required annotation
# - checked 21 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123560.2
# - root is http://omabrowser.org/ontology/oma#GROUP_146535
# - tree of groups fetched: 6
# - proteins within tree fetched: 7
# - uniprot proteins within tree fetched: 7
#   * check proteins (1-7): 0 with required annotation
# - checked 7 uniprot proteins: 0 with required annotation
# - checked 7 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123570.2
# - root is http://omabrowser.org/ontology/oma#GROUP_511597
# - tree of groups fetched: 458
# - proteins within tree fetched: 694
# - uniprot proteins within tree fetched: 675
#   * check proteins (1-694): 0 with required annotation
# - checked 675 uniprot proteins: 0 with required annotation
# - checked 694 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123580.2
# - root is http://omabrowser.org/ontology/oma#GROUP_144663
# - tree of groups fetched: 4
# - proteins within tree fetched: 5
# - uniprot proteins within tree fetched: 5
#   * check proteins (1-5): 0 with required annotation
# - checked 5 uniprot proteins: 0 with required annotation
# - checked 5 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123590.2
# - root is http://omabrowser.org/ontology/oma#GROUP_198431
# - tree of groups fetched: 41
# - proteins within tree fetched: 55
# - uniprot proteins within tree fetched: 57
#   * check proteins (1-55): 0 with required annotation
# - checked 57 uniprot proteins: 0 with required annotation
# - checked 55 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123600.2
# - root is http://omabrowser.org/ontology/oma#GROUP_497898
# - tree of groups fetched: 2548
# - proteins within tree fetched: 3934
# - uniprot proteins within tree fetched: 3426
#   * check proteins (1-3934): 0 with required annotation
# - checked 3426 uniprot proteins: 0 with required annotation
# - checked 3934 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123610.2
# - root is http://omabrowser.org/ontology/oma#GROUP_497898
# - tree already created
# Search for Solyc03g123620.2
# - root is http://omabrowser.org/ontology/oma#GROUP_196971
# - tree of groups fetched: 38
# - proteins within tree fetched: 49
# - uniprot proteins within tree fetched: 46
#   * check proteins (1-49): 0 with required annotation
# - checked 46 uniprot proteins: 0 with required annotation
# - checked 49 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123630.2
# - root is http://omabrowser.org/ontology/oma#GROUP_191779
# - tree of groups fetched: 53
# - proteins within tree fetched: 75
# - uniprot proteins within tree fetched: 71
#   * check proteins (1-75): 0 with required annotation
# - checked 71 uniprot proteins: 0 with required annotation
# - checked 75 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123640.2
# - root is http://omabrowser.org/ontology/oma#GROUP_515051
# - tree of groups fetched: 241
# - proteins within tree fetched: 383
# - uniprot proteins within tree fetched: 307
#   * check proteins (1-383): 0 with required annotation
# - checked 307 uniprot proteins: 0 with required annotation
# - checked 383 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123650.1
# - root is http://omabrowser.org/ontology/oma#GROUP_143183
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 2
#   * check proteins (1-2): 0 with required annotation
# - checked 2 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123660.2
# - root is http://omabrowser.org/ontology/oma#GROUP_493644
# - tree of groups fetched: 268
# - proteins within tree fetched: 432
# - uniprot proteins within tree fetched: 333
#   * check proteins (1-432): 0 with required annotation
# - checked 333 uniprot proteins: 0 with required annotation
# - checked 432 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123670.2
# - root is http://omabrowser.org/ontology/oma#GROUP_185695
# - tree of groups fetched: 15
# - proteins within tree fetched: 21
# - uniprot proteins within tree fetched: 21
#   * check proteins (1-21): 0 with required annotation
# - checked 21 uniprot proteins: 0 with required annotation
# - checked 21 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123680.1
# - root is http://omabrowser.org/ontology/oma#GROUP_200718
# - tree of groups fetched: 71
# - proteins within tree fetched: 91
# - uniprot proteins within tree fetched: 95
#   * check proteins (1-91): 0 with required annotation
# - checked 95 uniprot proteins: 0 with required annotation
# - checked 91 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123690.1
# - root is http://omabrowser.org/ontology/oma#GROUP_205967
# - tree of groups fetched: 3
# - proteins within tree fetched: 4
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-4): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 4 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123700.2
# - root is http://omabrowser.org/ontology/oma#GROUP_146528
# - tree of groups fetched: 5
# - proteins within tree fetched: 6
# - uniprot proteins within tree fetched: 6
#   * check proteins (1-6): 0 with required annotation
# - checked 6 uniprot proteins: 0 with required annotation
# - checked 6 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123710.2
# - root is http://omabrowser.org/ontology/oma#GROUP_145254
# - tree of groups fetched: 2
# - proteins within tree fetched: 3
# - uniprot proteins within tree fetched: 3
#   * check proteins (1-3): 0 with required annotation
# - checked 3 uniprot proteins: 0 with required annotation
# - checked 3 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123720.2
# - root is http://omabrowser.org/ontology/oma#GROUP_213110
# - tree of groups fetched: 70
# - proteins within tree fetched: 93
# - uniprot proteins within tree fetched: 79
#   * check proteins (1-93): 0 with required annotation
# - checked 79 uniprot proteins: 0 with required annotation
# - checked 93 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123730.2
# - root is http://omabrowser.org/ontology/oma#GROUP_494360
# - tree of groups fetched: 342
# - proteins within tree fetched: 522
# - uniprot proteins within tree fetched: 445
#   * check proteins (1-522): 0 with required annotation
# - checked 445 uniprot proteins: 0 with required annotation
# - checked 522 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123740.2
# - root is http://omabrowser.org/ontology/oma#GROUP_198403
# - tree of groups fetched: 79
# - proteins within tree fetched: 112
# - uniprot proteins within tree fetched: 109
#   * check proteins (1-112): 0 with required annotation
# - checked 109 uniprot proteins: 0 with required annotation
# - checked 112 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123750.2
# - root is http://omabrowser.org/ontology/oma#GROUP_206992
# - tree of groups fetched: 46
# - proteins within tree fetched: 84
# - uniprot proteins within tree fetched: 66
#   * check proteins (1-84): 0 with required annotation
# - checked 66 uniprot proteins: 0 with required annotation
# - checked 84 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123760.2
# - root is http://omabrowser.org/ontology/oma#GROUP_506684
# - tree of groups fetched: 66
# - proteins within tree fetched: 96
# - uniprot proteins within tree fetched: 98
#   * check proteins (1-96): 0 with required annotation
# - checked 98 uniprot proteins: 0 with required annotation
# - checked 96 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123770.1
# - no groups found
# Search for Solyc03g123780.2
# - root is http://omabrowser.org/ontology/oma#GROUP_192761
# - tree of groups fetched: 50
# - proteins within tree fetched: 68
# - uniprot proteins within tree fetched: 60
#   * check proteins (1-68): 0 with required annotation
# - checked 60 uniprot proteins: 0 with required annotation
# - checked 68 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123790.2
# - root is http://omabrowser.org/ontology/oma#GROUP_714413
# - tree of groups fetched: 513
# - proteins within tree fetched: 813
# - uniprot proteins within tree fetched: 674
#   * check proteins (1-813): 0 with required annotation
# - checked 674 uniprot proteins: 0 with required annotation
# - checked 813 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123800.1
# - root is http://omabrowser.org/ontology/oma#GROUP_500414
# - tree already created
# Search for Solyc03g123810.1
# - no groups found
# Search for Solyc03g123820.1
# - root is http://omabrowser.org/ontology/oma#GROUP_511499
# - tree already created
# Search for Solyc03g123830.2
# - root is http://omabrowser.org/ontology/oma#GROUP_515692
# - tree of groups fetched: 1328
# - proteins within tree fetched: 2149
# - uniprot proteins within tree fetched: 1786
#   * check proteins (1-2149): 0 with required annotation
# - checked 1786 uniprot proteins: 0 with required annotation
# - checked 2149 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123840.2
# - root is http://omabrowser.org/ontology/oma#GROUP_504340
# - tree of groups fetched: 164
# - proteins within tree fetched: 239
# - uniprot proteins within tree fetched: 202
#   * check proteins (1-239): 0 with required annotation
# - checked 202 uniprot proteins: 0 with required annotation
# - checked 239 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123850.2
# - no groups found
# Search for Solyc03g123860.2
# - root is http://omabrowser.org/ontology/oma#GROUP_207134
# - tree of groups fetched: 65
# - proteins within tree fetched: 88
# - uniprot proteins within tree fetched: 87
#   * check proteins (1-88): 0 with required annotation
# - checked 87 uniprot proteins: 0 with required annotation
# - checked 88 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123870.2
# - root is http://omabrowser.org/ontology/oma#GROUP_515165
# - tree of groups fetched: 100
# - proteins within tree fetched: 133
# - uniprot proteins within tree fetched: 136
#   * check proteins (1-133): 0 with required annotation
# - checked 136 uniprot proteins: 0 with required annotation
# - checked 133 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123880.2
# - root is http://omabrowser.org/ontology/oma#GROUP_215052
# - tree of groups fetched: 49
# - proteins within tree fetched: 62
# - uniprot proteins within tree fetched: 55
#   * check proteins (1-62): 0 with required annotation
# - checked 55 uniprot proteins: 0 with required annotation
# - checked 62 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123890.2
# - root is http://omabrowser.org/ontology/oma#GROUP_511598
# - tree already created
# Search for Solyc03g123900.2
# - root is http://omabrowser.org/ontology/oma#GROUP_706041
# - tree of groups fetched: 1225
# - proteins within tree fetched: 1912
# - uniprot proteins within tree fetched: 1510
#   * check proteins (1-1912): 0 with required annotation
# - checked 1510 uniprot proteins: 0 with required annotation
# - checked 1912 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123910.2
# - root is http://omabrowser.org/ontology/oma#GROUP_707096
# - tree of groups fetched: 276
# - proteins within tree fetched: 399
# - uniprot proteins within tree fetched: 307
#   * check proteins (1-399): 0 with required annotation
# - checked 307 uniprot proteins: 0 with required annotation
# - checked 399 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123920.2
# - root is http://omabrowser.org/ontology/oma#GROUP_208770
# - tree of groups fetched: 109
# - proteins within tree fetched: 156
# - uniprot proteins within tree fetched: 150
#   * check proteins (1-156): 0 with required annotation
# - checked 150 uniprot proteins: 0 with required annotation
# - checked 156 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123930.1
# - root is http://omabrowser.org/ontology/oma#GROUP_206410
# - tree of groups fetched: 2
# - proteins within tree fetched: 4
# - uniprot proteins within tree fetched: 1
#   * check proteins (1-4): 0 with required annotation
# - checked 1 uniprot proteins: 0 with required annotation
# - checked 4 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123940.1
# - root is http://omabrowser.org/ontology/oma#GROUP_496980
# - tree of groups fetched: 405
# - proteins within tree fetched: 749
# - uniprot proteins within tree fetched: 566
#   * check proteins (1-749): 0 with required annotation
# - checked 566 uniprot proteins: 0 with required annotation
# - checked 749 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123950.2
# - root is http://omabrowser.org/ontology/oma#GROUP_210170
# - tree of groups fetched: 43
# - proteins within tree fetched: 57
# - uniprot proteins within tree fetched: 62
#   * check proteins (1-57): 0 with required annotation
# - checked 62 uniprot proteins: 0 with required annotation
# - checked 57 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123960.2
# - root is http://omabrowser.org/ontology/oma#GROUP_210006
# - tree of groups fetched: 44
# - proteins within tree fetched: 57
# - uniprot proteins within tree fetched: 56
#   * check proteins (1-57): 0 with required annotation
# - checked 56 uniprot proteins: 0 with required annotation
# - checked 57 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123970.1
# - no groups found
# Search for Solyc03g123980.2
# - root is http://omabrowser.org/ontology/oma#GROUP_196601
# - tree of groups fetched: 62
# - proteins within tree fetched: 83
# - uniprot proteins within tree fetched: 76
#   * check proteins (1-83): 0 with required annotation
# - checked 76 uniprot proteins: 0 with required annotation
# - checked 83 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g123990.2
# - root is http://omabrowser.org/ontology/oma#GROUP_498805
# - tree already created
# Search for Solyc03g124000.1
# - root is http://omabrowser.org/ontology/oma#GROUP_145631
# - tree of groups fetched: 1
# - proteins within tree fetched: 2
# - uniprot proteins within tree fetched: 1
#   * check proteins (1-2): 0 with required annotation
# - checked 1 uniprot proteins: 0 with required annotation
# - checked 2 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124010.2
# - root is http://omabrowser.org/ontology/oma#GROUP_211195
# - tree of groups fetched: 36
# - proteins within tree fetched: 51
# - uniprot proteins within tree fetched: 55
#   * check proteins (1-51): 0 with required annotation
# - checked 55 uniprot proteins: 0 with required annotation
# - checked 51 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124020.1
# - root is http://omabrowser.org/ontology/oma#GROUP_183969
# - tree of groups fetched: 47
# - proteins within tree fetched: 68
# - uniprot proteins within tree fetched: 66
#   * check proteins (1-68): 0 with required annotation
# - checked 66 uniprot proteins: 0 with required annotation
# - checked 68 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124030.2
# - root is http://omabrowser.org/ontology/oma#GROUP_212526
# - tree of groups fetched: 39
# - proteins within tree fetched: 55
# - uniprot proteins within tree fetched: 48
#   * check proteins (1-55): 0 with required annotation
# - checked 48 uniprot proteins: 0 with required annotation
# - checked 55 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124040.2
# - root is http://omabrowser.org/ontology/oma#GROUP_211290
# - tree of groups fetched: 35
# - proteins within tree fetched: 50
# - uniprot proteins within tree fetched: 50
#   * check proteins (1-50): 0 with required annotation
# - checked 50 uniprot proteins: 0 with required annotation
# - checked 50 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124050.2
# - root is http://omabrowser.org/ontology/oma#GROUP_181844
# - tree of groups fetched: 47
# - proteins within tree fetched: 61
# - uniprot proteins within tree fetched: 57
#   * check proteins (1-61): 0 with required annotation
# - checked 57 uniprot proteins: 0 with required annotation
# - checked 61 proteins: 0 linked to uniprot with required annotation
# Search for Solyc03g124060.2
# - root is http://omabrowser.org/ontology/oma#GROUP_210114
# - tree of groups fetched: 50
# - proteins within tree fetched: 70
# - uniprot proteins within tree fetched: 64
#   * check proteins (1-70): 0 with required annotation
# - checked 64 uniprot proteins: 0 with required annotation
# - checked 70 proteins: 0 linked to uniprot with required annotation
# === COMPUTATIONS ===
# Compute for Solyc03g121600.2
# Compute for Solyc03g121610.2
# Compute for Solyc03g121620.1
# Compute for Solyc03g121630.2
# Compute for Solyc03g121640.2
# Compute for Solyc03g121650.2
# Compute for Solyc03g121660.2
# Compute for Solyc03g121670.2
# Compute for Solyc03g121680.1
# Compute for Solyc03g121690.1
# Compute for Solyc03g121700.2
# Compute for Solyc03g121710.2
# Compute for Solyc03g121720.2
# Compute for Solyc03g121730.2
# Compute for Solyc03g121740.1
# Skip Solyc03g121750.1
# Compute for Solyc03g121760.2
# Compute for Solyc03g121770.1
# Compute for Solyc03g121780.1
# Compute for Solyc03g121790.2
# Compute for Solyc03g121800.2
# Compute for Solyc03g121810.2
# Compute for Solyc03g121820.2
# Compute for Solyc03g121830.1
# Compute for Solyc03g121840.2
# Compute for Solyc03g121850.2
# Compute for Solyc03g121860.1
# Compute for Solyc03g121870.2
# Skip Solyc03g121880.2
# Compute for Solyc03g121890.1
# Compute for Solyc03g121900.1
# Compute for Solyc03g121910.1
# Compute for Solyc03g121920.2
# Compute for Solyc03g121930.2
# Compute for Solyc03g121940.2
# Compute for Solyc03g121950.2
# Compute for Solyc03g121960.2
# Compute for Solyc03g121970.1
# Compute for Solyc03g121980.2
# Compute for Solyc03g121990.2
# Skip Solyc03g122000.2
# Compute for Solyc03g122010.1
# Compute for Solyc03g122020.2
# Compute for Solyc03g122030.1
# Compute for Solyc03g122040.2
# Skip Solyc03g122050.1
# Skip Solyc03g122060.1
# Compute for Solyc03g122070.1
# Compute for Solyc03g122080.2
# Compute for Solyc03g122090.2
# Compute for Solyc03g122100.1
# Compute for Solyc03g122110.1
# Compute for Solyc03g122120.2
# Compute for Solyc03g122130.2
# Compute for Solyc03g122140.2
# Compute for Solyc03g122150.2
# Skip Solyc03g122160.1
# Compute for Solyc03g122170.2
# Compute for Solyc03g122180.2
# Compute for Solyc03g122190.2
# Compute for Solyc03g122200.1
# Compute for Solyc03g122210.1
# Compute for Solyc03g122220.1
# Compute for Solyc03g122230.1
# Compute for Solyc03g122240.2
# Compute for Solyc03g122250.2
# Compute for Solyc03g122260.2
# Compute for Solyc03g122270.2
# Skip Solyc03g122280.2
# Compute for Solyc03g122290.2
# Compute for Solyc03g122300.1
# Compute for Solyc03g122310.2
# Compute for Solyc03g122320.1
# Compute for Solyc03g122330.1
# Compute for Solyc03g122340.2
# Compute for Solyc03g122350.2
# Compute for Solyc03g122360.2
# Compute for Solyc03g122370.2
# Compute for Solyc03g123370.2
# Compute for Solyc03g123380.1
# Compute for Solyc03g123390.2
# Compute for Solyc03g123400.1
# Compute for Solyc03g123410.1
# Compute for Solyc03g123420.1
# Compute for Solyc03g123430.2
# Compute for Solyc03g123440.2
# Skip Solyc03g123450.1
# Compute for Solyc03g123460.2
# Compute for Solyc03g123470.1
# Skip Solyc03g123480.1
# Compute for Solyc03g123490.1
# Compute for Solyc03g123500.2
# Compute for Solyc03g123510.1
# Compute for Solyc03g123520.2
# Compute for Solyc03g123530.2
# Compute for Solyc03g123540.2
# Compute for Solyc03g123550.1
# Compute for Solyc03g123560.2
# Compute for Solyc03g123570.2
# Compute for Solyc03g123580.2
# Compute for Solyc03g123590.2
# Compute for Solyc03g123600.2
# Compute for Solyc03g123610.2
# Compute for Solyc03g123620.2
# Compute for Solyc03g123630.2
# Compute for Solyc03g123640.2
# Compute for Solyc03g123650.1
# Compute for Solyc03g123660.2
# Compute for Solyc03g123670.2
# Compute for Solyc03g123680.1
# Compute for Solyc03g123690.1
# Compute for Solyc03g123700.2
# Compute for Solyc03g123710.2
# Compute for Solyc03g123720.2
# Compute for Solyc03g123730.2
# Compute for Solyc03g123740.2
# Compute for Solyc03g123750.2
# Compute for Solyc03g123760.2
# Skip Solyc03g123770.1
# Compute for Solyc03g123780.2
# Compute for Solyc03g123790.2
# Compute for Solyc03g123800.1
# Skip Solyc03g123810.1
# Compute for Solyc03g123820.1
# Compute for Solyc03g123830.2
# Compute for Solyc03g123840.2
# Skip Solyc03g123850.2
# Compute for Solyc03g123860.2
# Compute for Solyc03g123870.2
# Compute for Solyc03g123880.2
# Compute for Solyc03g123890.2
# Compute for Solyc03g123900.2
# Compute for Solyc03g123910.2
# Compute for Solyc03g123920.2
# Compute for Solyc03g123930.1
# Compute for Solyc03g123940.1
# Compute for Solyc03g123950.2
# Compute for Solyc03g123960.2
# Skip Solyc03g123970.1
# Compute for Solyc03g123980.2
# Compute for Solyc03g123990.2
# Compute for Solyc03g124000.1
# Compute for Solyc03g124010.2
# Compute for Solyc03g124020.1
# Compute for Solyc03g124030.2
# Compute for Solyc03g124040.2
# Compute for Solyc03g124050.2
# Compute for Solyc03g124060.2
# === CREATED QTLSEARCH OBJECT ===

# %% [markdown]
# Create report

# %%
report_list = result.report()
for report in report_list:
    display(report)
# Out:
#                   p_initial   p_final  \
# gene
# Solyc03g121600.2   0.006757  0.006757
# Solyc03g121610.2   0.006757  0.006757
# Solyc03g121620.1   0.006757  0.006757
# Solyc03g121630.2   0.006757  0.006757
# Solyc03g121640.2   0.006757  0.006757
# ...                     ...       ...
# Solyc03g122220.1   0.006757  0.000000
# Solyc03g122350.2   0.006757  0.000000
# Solyc03g122360.2   0.006757  0.000000
# Solyc03g123470.1   0.006757  0.000000
# Solyc03g123800.1   0.006757  0.000000
#
#                                                      protein
# gene
# Solyc03g121600.2  https://omabrowser.org/oma/info/SOLLC18181
# Solyc03g121610.2  https://omabrowser.org/oma/info/SOLLC18182
# Solyc03g121620.1  https://omabrowser.org/oma/info/SOLLC18183
# Solyc03g121630.2  https://omabrowser.org/oma/info/SOLLC18184
# Solyc03g121640.2  https://omabrowser.org/oma/info/SOLLC18185
# ...                                                      ...
# Solyc03g122220.1  https://omabrowser.org/oma/info/SOLLC18242
# Solyc03g122350.2  https://omabrowser.org/oma/info/SOLLC18255
# Solyc03g122360.2  https://omabrowser.org/oma/info/SOLLC18256
# Solyc03g123470.1  https://omabrowser.org/oma/info/SOLLC18267
# Solyc03g123800.1  https://omabrowser.org/oma/info/SOLLC18300
#
# [135 rows x 3 columns]
